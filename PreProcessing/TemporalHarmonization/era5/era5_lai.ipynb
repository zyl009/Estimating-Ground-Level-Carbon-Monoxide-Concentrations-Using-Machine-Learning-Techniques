# %%
import xarray as xr

# %%
# Load GRIB file using the cfgrib engine
lai = xr.open_dataset("/path/to/lai.grib", engine="cfgrib")

# View the dataset
lai

# %%
lai=lai.to_dataframe()
lai.reset_index(drop=False, inplace=True)
lai
# Out:
#                        time  latitude  longitude  number   step  surface  \
# 0       2019-01-01 00:00:00     45.95       8.40       0 0 days      0.0
# 1       2019-01-01 00:00:00     45.95       8.65       0 0 days      0.0
# 2       2019-01-01 00:00:00     45.95       8.90       0 0 days      0.0
# 3       2019-01-01 00:00:00     45.95       9.15       0 0 days      0.0
# 4       2019-01-01 00:00:00     45.95       9.40       0 0 days      0.0
# ...                     ...       ...        ...     ...    ...      ...
# 1262587 2024-12-31 23:00:00     45.20       8.65       0 0 days      0.0
# 1262588 2024-12-31 23:00:00     45.20       8.90       0 0 days      0.0
# 1262589 2024-12-31 23:00:00     45.20       9.15       0 0 days      0.0
# 1262590 2024-12-31 23:00:00     45.20       9.40       0 0 days      0.0
# 1262591 2024-12-31 23:00:00     45.20       9.65       0 0 days      0.0
#
#                  valid_time    lai_hv    lai_lv
# ...

# %%
lai.to_feather('/path/to/lai.feather')
